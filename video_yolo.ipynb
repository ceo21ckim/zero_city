# %%
import torch 
import os, cv2
import re

# %%
path = "../origin_data/images/jaywalks"
paths = [os.path.join(path , i ) for i in os.listdir(path) if re.search(".jpg$", i )]

pathIn= '../origin_data/images/jaywalks'
pathOut = '../video/jaywalks.mp4'
fps = 30
frame_array = []
for idx , path in enumerate(paths) : 
    if (idx % 2 == 0) | (idx % 5 == 0) :
        continue
    img = cv2.imread(path)
    height, width, layers = img.shape
    size = (width,height)
    frame_array.append(img)
out = cv2.VideoWriter(pathOut,cv2.VideoWriter_fourcc(*'DIVX'), fps, size)
for i in range(len(frame_array)):
    # writing to a image array
    out.write(frame_array[i])
out.release()

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Using cache found in C:\Users\Bigdata21/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-5-26 Python-3.7.11 torch-1.10.0+cu113 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12288MiB)
#
# Fusing layers...

# %%
# !python detect.py --source ../video/jaywalks.mp4
# Out:
# detect: weights=yolov5s.pt, source=../video/jaywalks.mp4, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  v6.1-223-g1dcb774 Python-3.7.11 torch-1.10.0+cu113 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12288MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.5 GFLOPs
# video 1/1 (1/559) C:\Users\Bigdata21\Desktop\KIMDONGEON\ML_final_assignment\video\jaywalks.mp4: 384x640 2 persons, 17 cars, 2 buss, 2 traffic lights, Done. (0.004s)
# video 1/1 (2/559) C:\Users\Bigdata21\Desktop\KIMDONGEON\ML_final_assignment\video\jaywalks.mp4: 384x640 1 person, 19 cars, 1 bus, 2 traffic lights, Done. (0.013s)
# ...
